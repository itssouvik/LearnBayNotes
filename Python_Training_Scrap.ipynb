# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Loop statement
x = 'india'

for j in x:
    print(j)
# Out:
# i
# n
# d
# i
# a

# %%
# \t - inserts a tab
# \n - inserts a new line
# \ - considers as the same line 
# \b - deletes the last character

# %%
# Derived Data types:
# List and Tuples

# %%
#type casting
age = float(input("Enter age of person"))
print(age)
print (type(age))

#float to int

x=56.3
print(type(x))
y=int(x)
print (y)
print(type(y))

# String to float

x=56.3
print(type(x))
y=float(x)
print (y)
print(type(y))
# Out:
# Enter age of personfdgfd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 #type casting
# ----> 2 age = float(input("Enter age of person"))
#       3 print(age)
#       4 print (type(age))
#
# ValueError: could not convert string to float: 'fdgfd'

# %%
#Indexing
x = 'python'
print(x[3])
print(x[-5])
print(x[1])
print(len(x))
# Out:
# h
# y
# y
# 6

# %%
#mutable and immutable
#List is mutable and Tuple & String are immutable

# %%
#concatenation 
#this is used for concatenating different data types else just adding strings are straight forward

#repetation
x = 'india '
y = 'python'
z=x*3+y
print(z)
# Out:
# india india india python

# %%
#Slicing
#note: last position is excluded so add one extra position  
#Step also decides the direction
x= 'python'
print(x[1:4:1])
print(x[0:5:2])

print(x[-6:-2:1])
print(x[-6:-2:2])

print(x[-1:-7:-1])
# Out:
# yth
# pto
# pyth
# pt
# nohtyp

# %%
#Methods of string
print (dir())
print("very good. keep it up")
print (dir(str))
# Out:
# ['In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i37', '_i38', '_i4', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'age', 'exit', 'get_ipython', 'j', 'keyword', 'open', 'quit', 'x', 'y', 'z']
# very good. keep it up
# ...

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
#Check the 3rd youtube video aT 49 minutes --- ???
